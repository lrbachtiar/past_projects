# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import glob

# %% [markdown]
# ## 2015 data

# %%
path = './data/raw_data'
allFiles = glob.glob(path + "/*.csv")
df_name = {x.replace(path+'/', '').replace('.csv', '') for x in allFiles}

# %%
# atp_matches_2015
# atp_matches_futures_2015
# atp_matches_qual_chall_2015

# %%
matches = pd.read_csv(str(path+'/atp_matches_2015.csv'), header=0, encoding = "ISO-8859-1")

# %%
matches
# Out:
#      tourney_id                 tourney_name surface  draw_size tourney_level  \
# 0      2015-329                        Tokyo    Hard         32             A
# 1      2015-329                        Tokyo    Hard         32             A
# 2      2015-329                        Tokyo    Hard         32             A
# 3      2015-329                        Tokyo    Hard         32             A
# 4      2015-329                        Tokyo    Hard         32             A
# 5      2015-329                        Tokyo    Hard         32             A
# 6      2015-329                        Tokyo    Hard         32             A
# 7      2015-329                        Tokyo    Hard         32             A
# 8      2015-329                        Tokyo    Hard         32             A
# 9      2015-329                        Tokyo    Hard         32             A
# 10     2015-329                        Tokyo    Hard         32             A
# ...

# %%
str(path+'/atp_players.csv')
# Out:
# './data/raw_data/atp_players.csv'

# %%
players = pd.read_csv(str(path+'/atp_players.csv'), header=0, encoding = "ISO-8859-1")

# %%
len(gen_df[gen_df['Survived']==1])

# %%
match_surface = matches.surface.unique()

# %%
match_surface = matches.surface.unique()

# %%
surface_type
# Out:
# array(['Hard', 'Clay', 'Grass'], dtype=object)

# %%
surf_count = []
for match_surface in matches.surface.unique():
    surf_count.append(len(matches[matches['surface']==match_surface]))

# %%
surf_count
# Out:
# [1702, 928, 328]

# %%
tourneys = matches.tourney_id.unique()

# %%
matches.groupby('tourney_id').size().head()
# Out:
# tourney_id
# 2015-1536    55
# 2015-2276    27
# 2015-301     27
# 2015-308     27
# 2015-311     31
# dtype: int64

# %%
len(tourneys)
# Out:
# 148

# %%
tourneys
# Out:
# array(['2015-329', '2015-429', '2015-439', '2015-422', '2015-5014',
#        '2015-352', '2015-425', '2015-7163', '2015-540', '2015-7161',
#        '2015-421', '2015-6003', '2015-6120', '2015-407', '2015-891',
#        '2015-404', '2015-403', '2015-402', '2015-339', '2015-338',
#        '2015-6718', '2015-440', '2015-500', '2015-495', '2015-560',
#        '2015-6967', '2015-773', '2015-337', '2015-311', '2015-6932',
#        '2015-315', '2015-314', '2015-741', '2015-319', '2015-580',
#        '2015-316', '2015-506', '2015-807', '2015-573', '2015-6242',
#        '2015-2276', '2015-308', '2015-418', '2015-6116', '2015-414',
#        '2015-1536', '2015-416', '2015-375', '2015-410', '2015-533',
#        '2015-451', '2015-360', '2015-438', '2015-341', '2015-717',
#        '2015-301', '2015-496', '2015-322', '2015-321', '2015-7290',
#        '2015-568', '2015-747', '2015-499', '2015-328', '2015-520',
#        '2015-605', '2015-6406', '2015-D001', '2015-D002', '2015-D003',
# ...
